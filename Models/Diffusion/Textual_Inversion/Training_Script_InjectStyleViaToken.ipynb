# %%
# mount with drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 🚀 Install everything you need
# !pip install -q diffusers==0.26.0
# !pip install -q transformers==4.41.0
# !pip install -q peft==0.15.1
# !pip install -q accelerate==1.6.0
# !pip install -q torch torchvision
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 36.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 103.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 108.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.0/411.0 kB 11.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 128.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 100.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 42.9 MB/s eta 0:00:00
# ...

# %%
from transformers import CLIPTokenizer
tok = CLIPTokenizer.from_pretrained("openai/clip-vit-large-patch14")
print(tok.tokenize("<cdsstyle>"))
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/905 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/961k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# ['<</w>', 'c', 'ds', 'style</w>', '></w>']

# %%
print(tok.tokenize("<stylii>"))
# Out:
# ['<</w>', 'styli', 'i</w>', '></w>']

# %%
# !wget https://raw.githubusercontent.com/huggingface/diffusers/main/examples/textual_inversion/textual_inversion.py
# Out:
# --2025-05-15 18:57:08--  https://raw.githubusercontent.com/huggingface/diffusers/main/examples/textual_inversion/textual_inversion.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 40557 (40K) [text/plain]
# Saving to: ‘textual_inversion.py’
#
# textual_inversion.p 100%[===================>]  39.61K  --.-KB/s    in 0.008s
#
# 2025-05-15 18:57:08 (5.12 MB/s) - ‘textual_inversion.py’ saved [40557/40557]

# %%
# !pip install -q --upgrade diffusers accelerate transformers peft
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 59.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.1/362.1 kB 33.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 131.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.1/411.1 kB 30.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 97.2 MB/s eta 0:00:00

# %%
# !git clone https://github.com/huggingface/diffusers
# Out:
# Cloning into 'diffusers'...
# remote: Enumerating objects: 91655, done.
# remote: Counting objects: 100% (1079/1079), done.
# remote: Compressing objects: 100% (544/544), done.
# remote: Total 91655 (delta 920), reused 535 (delta 535), pack-reused 90576 (from 5)
# Receiving objects: 100% (91655/91655), 68.16 MiB | 30.32 MiB/s, done.
# Resolving deltas: 100% (67232/67232), done.

# %%
# %cd diffusers/examples/textual_inversion
# Out:
# /content/diffusers/examples/textual_inversion

# %%
# %cd /content/diffusers
# !pip uninstall -y diffusers
# !pip install -e .
# Out:
# /content/diffusers
# Found existing installation: diffusers 0.33.1
# Uninstalling diffusers-0.33.1:
#   Successfully uninstalled diffusers-0.33.1
# Obtaining file:///content/diffusers
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for diffusers (pyproject.toml) ... done
#   Created wheel for diffusers: filename=diffusers-0.34.0.dev0-0.editable-py3-none-any.whl size=11367 sha256=85ae570b04b4d182f970812137d07d13235dc6fab33af0ac096cdd14e8596e11
#   Stored in directory: /tmp/pip-ephem-wheel-cache-e26z7wkx/wheels/30/15/ca/ab6e88c89d6ba7047b3f155894c6c346e7cf06067fd132ae62
# Successfully built diffusers
# ...

# %%
# %cd /content/diffusers/examples/textual_inversion
# !accelerate launch textual_inversion.py \
  --pretrained_model_name_or_path runwayml/stable-diffusion-v1-5 \
  --train_data_dir /content/drive/MyDrive/stable_diffusion_data/images \
  --output_dir /content/stylii_embedding \
  --placeholder_token "<stylii>" \
  --initializer_token "illustration" \
  --resolution 512 \
  --train_batch_size 1 \
  --gradient_accumulation_steps 4 \
  --learning_rate 1e-4 \
  --max_train_steps 3000 \
  --lr_scheduler "constant"
# Out:
# /content/diffusers/examples/textual_inversion
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# 2025-05-15 19:02:14.168030: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-15 19:02:14.185908: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
# 1) Create a target folder in Drive (if it doesn’t already exist)
# !mkdir -p /content/drive/MyDrive/stylii_embedding

# 2) Copy all embedding files into that folder
# !cp /content/stylii_embedding/* /content/drive/MyDrive/stylii_embedding/

# %%
# !zip -r /content/stylii_embedding.zip /content/stylii_embedding
# Out:
#   adding: content/stylii_embedding/ (stored 0%)
#   adding: content/stylii_embedding/checkpoint-1500/ (stored 0%)
#   adding: content/stylii_embedding/checkpoint-1500/model.safetensors (deflated 31%)
#   adding: content/stylii_embedding/checkpoint-1500/random_states_0.pkl (deflated 25%)
#   adding: content/stylii_embedding/checkpoint-1500/optimizer.bin (deflated 100%)
#   adding: content/stylii_embedding/checkpoint-1500/scheduler.bin (deflated 55%)
#   adding: content/stylii_embedding/learned_embeds-steps-1500.safetensors (deflated 6%)
#   adding: content/stylii_embedding/checkpoint-3000/ (stored 0%)
#   adding: content/stylii_embedding/checkpoint-3000/model.safetensors (deflated 31%)
#   adding: content/stylii_embedding/checkpoint-3000/random_states_0.pkl (deflated 25%)
#   adding: content/stylii_embedding/checkpoint-3000/optimizer.bin (deflated 100%)
#   adding: content/stylii_embedding/checkpoint-3000/scheduler.bin (deflated 55%)
# ...

# %%
from google.colab import files

# Replace the file name below with the zip you created
files.download("/content/stylii_embedding.zip")
